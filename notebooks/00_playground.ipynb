# %%
# notebooks/00_playground.ipynb

import sys
import os

sys.path.append(os.path.abspath("../"))  # Pour trouver le dossier src

from src.visualizer import draw_piano_voicing, draw_guitar_chord

# %%
# 1. Piano: C Major (C - E - G)
# Indices: 0=C3, 1=D3...
draw_piano_voicing([0, 2, 4], title="C Major")

# 2. Guitar: C Major Open Chord
# Format: List of (string_index, fret)
# string_index: 0 (Low E) to 5 (High E)
# fret: -1 (Mute), 0 (Open), >0 (Fret)
c_major_guitar = [
    (0, -1),  # Low E Mute
    (1, 3),  # C
    (2, 2),  # E
    (3, 0),  # G
    (4, 1),  # C
    (5, 0),  # E
]
draw_guitar_chord(c_major_guitar, title="C Major Open")
